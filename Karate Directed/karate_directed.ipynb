# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
g1 = nx.karate_club_graph()
plt.tight_layout()
plt.figure(figsize=(15,10))
nx.draw_networkx(g1, arrows=True)
plt.title('Graph karate ')
plt.savefig("graph.png")
plt.show()
